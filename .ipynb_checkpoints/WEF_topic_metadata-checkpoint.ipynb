# %% [markdown]
# # 데이터 웹 크롤링

# %%
from bs4 import BeautifulSoup
import urllib.request as req # url 호출 라이브러리

# %%
url = "https://www.weforum.org/reports?page=%s"

rpTitle=[] # 제목 리스트 추출
for i in list(range(1,66)):
    url_list = url % (i)
    html = req.urlopen(url_list)
    bsObject = BeautifulSoup(html,"html.parser")
    res_list = bsObject.find_all("h3", class_="tout__title")
    for link in res_list: 
        res_list = link.get_text()
        rpTitle.append(res_list)

# %%
rpTitle[0:5]
# Out:
# ['Understanding Value in Media:\xa0Perspectives from Consumers and Industry',
#  'Mobilizing the Private Sector in Peace and Reconciliation',
#  'How Can Trade Rules Support Environmental Action?',
#  'Guidelines for City Mobility: Steering towards collaboration',
#  'Digitizing and Transforming Mobility Systems: Lessons from the Detroit Region']

# %%
rpDescription=[] # 요약 리스트 추출
for i in list(range(1,66)):
    url_list = url % (i)
    html = req.urlopen(url_list)
    bsObject = BeautifulSoup(html,"html.parser")
    res_list = bsObject.find_all("p", class_="tout__description")
    for link in res_list: 
        res_list = link.get_text()
        rpDescription.append(res_list)

# %%
rpDescription[0:5]
# Out:
# ["In an age of fake news and misinformation, good quality content is more valuable than ever. So who’s creating it, who’s paying for it and who's controlling its production? As the world ba...",
#  'The following report, authored by a team of researchers from the Graduate Institute Geneva tackles this question: Based on previous involvements of the private sector in peacebuilding, wh...',
#  'As governments and businesses grapple with the effects of COVID-19, other global challenges remain. Once the immediate crisis abates, countries must intensify environmental action to tack...',
#  'Developed by the World Economic Forum’s Global Future Council on Mobility, the Guidelines for Transforming City Mobility Systems reflect shared goals for liveable and just transport netwo...',
#  'The pilot demonstrated that the power of data rallies across sectors, interests and operating models. In a world that still suffers deeply from socioeconomic disparities, persisting racia...']

# %%
rpCaption=[] # 날짜 리스트 추출 
for i in list(range(1,66)):
    url_list = url % (i)
    html = req.urlopen(url_list)
    bsObject = BeautifulSoup(html,"html.parser")
    res_list = bsObject.find_all("div", class_="caption")
    for link in res_list: 
        res_list = link.get_text()
        rpCaption.append(res_list)

# %%
# " report -  "제거 
import re
for i in range(len(rpCaption)):
    rpCaption[i]=re.sub("Report| — ","",rpCaption[i])

# %%
rpCaption[0]
# Out:
# '2 April 2020'

# %% [markdown]
# # 데이터 프레임 생성

# %%
import pandas as pd

# %%
WEFdata=pd.DataFrame(rpCaption,columns=['date'])
WEFdata['title']=pd.DataFrame(rpTitle,columns=['title'])
WEFdata['summary']=pd.DataFrame(rpDescription,columns=['summary'])

# %%
WEFdata.to_csv("WEFdata.csv") # 원데이터 생성

# %%
WEFdata['document']=WEFdata['title']+WEFdata['summary']
WEFdf=pd.DataFrame({'document':WEFdata['document']})
WEFdf # 토픽모델링할 데이터 생성
# Out:
#                                               document
# 0    Understanding Value in Media: Perspectives fro...
# 1    Mobilizing the Private Sector in Peace and Rec...
# 2    How Can Trade Rules Support Environmental Acti...
# 3    Guidelines for City Mobility: Steering towards...
# 4    Digitizing and Transforming Mobility Systems: ...
# 5    Insights on handling coronavirus from an earli...
# 6    Argentina’s Travel and Tourism Competitiveness...
# 7    Global Data Access for Solving Rare Disease: A...
# 8    Davos 2020: Global Media CoverageDiscover an o...
# 9    Energy Policy Lighthouses: The Little Green Bo...
# 3글자 이하 제거 
WEFdf['clean_doc'] = WEFdf['clean_doc'].apply(lambda x:" ".join([w for w in x.split() if len(w)>3]))

# %%
# 소문자 변환 
WEFdf['clean_doc'] = WEFdf['clean_doc'].apply(lambda x:x.lower())

# %%
# 불용어 제거 
from nltk.corpus import stopwords
stopword = stopwords.words('english')

tokenizedDoc = WEFdf['clean_doc'].apply(lambda x:x.split())
tokenizedDoc = tokenizedDoc.apply(lambda x : [item for item in x if item not in stopword])

# %% [markdown]
# # TF-IDF 매트릭스 구성

# %%
# 역 토큰화 
deTokenizedDoc = []
for i in range(len(WEFdf)):
    temp = " ".join(tokenizedDoc[i])
    deTokenizedDoc.append(temp)

WEFdf['clean_doc'] = deTokenizedDoc

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
vector = TfidfVectorizer(stop_words="english", max_features=500)
res = vector.fit_transform(WEFdf['clean_doc'])
res.shape
# Out:
# (780, 500)

# %%
from sklearn.decomposition import TruncatedSVD
svdModel = TruncatedSVD(n_components=20)
svdModel.fit(res)
# Out:
# TruncatedSVD(algorithm='randomized', n_components=20, n_iter=5,
#        random_state=None, tol=0.0)

# %%
import numpy as np
np.shape(svdModel.components_)
# Out:
# (20, 500)

# %%
terms=vector.get_feature_names()

# %% [markdown]
# # 토픽 추출

# %%
def getTopic(model, fName, n=5):
    for i , t in enumerate(model):
        print("토픽: %d" %(i+1), [(fName[i],t[i].round(5)) 
                                for i in t.argsort()[:-n-1:-1]])

# %%
getTopic(svdModel.components_,terms) # 주제추출이 어렵군..
# Out:
# 토픽: 1 [('global', 0.42351), ('world', 0.30294), ('economic', 0.29383), ('report', 0.29274), ('forum', 0.24767)]
# 토픽: 2 [('risks', 0.45416), ('global', 0.39445), ('executive', 0.18907), ('summary', 0.18723), ('agenda', 0.14287)]
# 토픽: 3 [('risks', 0.46086), ('meeting', 0.24187), ('summary', 0.23505), ('annual', 0.22257), ('executive', 0.22147)]
# 토픽: 4 [('competitiveness', 0.47471), ('report', 0.32312), ('africa', 0.16491), ('gender', 0.13746), ('growth', 0.08317)]
# 토픽: 5 [('energy', 0.4058), ('report', 0.37114), ('competitiveness', 0.27441), ('architecture', 0.18109), ('gender', 0.1496)]
# 토픽: 6 [('mineral', 0.41232), ('development', 0.3566), ('financial', 0.27983), ('value', 0.26814), ('responsible', 0.21554)]
# 토픽: 7 [('annual', 0.40543), ('financial', 0.30144), ('meeting', 0.29716), ('champions', 0.18533), ('technology', 0.15417)]
# 토픽: 8 [('financial', 0.49955), ('africa', 0.26102), ('services', 0.24626), ('future', 0.14275), ('innovation', 0.1306)]
# 토픽: 9 [('financial', 0.42279), ('economic', 0.14142), ('services', 0.13986), ('gender', 0.13853), ('crisis', 0.12893)]
# 토픽: 10 [('gender', 0.50718), ('technology', 0.21815), ('information', 0.14734), ('forum', 0.12364), ('parity', 0.12087)]
# 토픽: 11 [('technology', 0.3758), ('information', 0.28936), ('competitiveness', 0.18792), ('world', 0.13613), ('forum', 0.11923)]
# 토픽: 12 [('growth', 0.48333), ('companies', 0.26391), ('community', 0.20181), ('economic', 0.17638), ('social', 0.11706)]
# 토픽: 13 [('trade', 0.63001), ('enabling', 0.23105), ('infrastructure', 0.18144), ('world', 0.13419), ('private', 0.10351)]
# 토픽: 14 [('trade', 0.4933), ('africa', 0.27265), ('enabling', 0.18555), ('technology', 0.15892), ('growth', 0.15094)]
# 토픽: 15 [('risk', 0.47895), ('report', 0.1506), ('risks', 0.11673), ('value', 0.09089), ('africa', 0.0829)]
# 토픽: 16 [('technology', 0.3236), ('infrastructure', 0.28284), ('information', 0.26939), ('africa', 0.15647), ('development', 0.1499)]
# 토픽: 17 [('education', 0.38232), ('initiative', 0.22061), ('development', 0.19627), ('industrial', 0.1702), ('fourth', 0.16465)]
# 토픽: 18 [('industrial', 0.25671), ('fourth', 0.25217), ('revolution', 0.20642), ('asia', 0.17888), ('risk', 0.15923)]
# 토픽: 19 [('value', 0.22245), ('community', 0.22069), ('infrastructure', 0.16026), ('companies', 0.15449), ('digital', 0.13917)]
# 토픽: 20 [('education', 0.38683), ('emerging', 0.25304), ('systems', 0.18881), ('markets', 0.16457), ('health', 0.13731)]

# %% [markdown]
# # 워드클라우드 생성

# %%
# vectorizer 내에서 높은 순위로 고려되는 단어들을 불러오는 함수를 생성 
def rank_words(terms, feature_matrix):
    sums = feature_matrix.sum(axis=0) # 문서마다 단어의 tfidf 합산
    data = []
    for col, term in enumerate(terms): 
        data.append( (term, sums[0,col])) # 단어의 tfidf 값 매핑하여 리스트에 추가
    ranked = pd.DataFrame(data, columns=['term','rank']).sort_values('rank',ascending=False) 
    # tfidf 내림차순으로 정렬하여 데이터프레임 생성  
    return ranked 

ranked = rank_words(terms=vector.get_feature_names(), feature_matrix=res)

# %%
import matplotlib.pyplot as plt
# 워드클라우드로 idf 역행렬로 얻어진 단어들의 빈도수를 시각화 
dic = {ranked.loc[i,'term'].upper() : ranked.loc[i,'rank']
      for i in range(0,len(ranked))}

from wordcloud import WordCloud
wordcloud = WordCloud(background_color="white",
                     max_words=100,
                     colormap="Reds").generate_from_frequencies(dic)

fig = plt.figure(1, figsize=(12,15))
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
plt.show()

# %% [markdown]
# 줄거리가 비슷한 보고서 추천하기

# %%
# tfidf 행렬 생성 
from sklearn.feature_extraction.text import TfidfVectorizer
tfidf=TfidfVectorizer(stop_words='english')#불용어 제거 
tfidf_mat=tfidf.fit_transform(WEFdata['summary']).toarray()

# %%
#코사인유사도함수 2 (분모=!0)
from numpy.linalg import norm
def cos_sim2(X,Y):
    return np.dot(X,Y)/((norm(X)*norm(Y))+1e-7)

# %%
#추천 함수 
def top_match_ar2(data, name, rank=5,simf=cos_sim2):
    sim=[]
    for i in range(len(data)):
        if name != i:
            sim.append((simf(data[i],data[name]),i))
    sim.sort()
    sim.reverse()
    return sim[:rank]

# %%
WEFdata.loc[0].title
# Out:
# 'Understanding Value in Media:\xa0Perspectives from Consumers and Industry'

# %%
# 코사인유사도가 비슷한 순으로 보고서 추천 : (보고서제목, 코사인유사도) 
reportList = [] 
for sim, report_id in top_match_ar2(tfidf_mat,0,5):
    reportList.append((sim, WEFdata.loc[report_id,'title']))
reportList[:10]
# Out:
# [(0.13529874188785931,
#   'The Impact of Digital Content: Opportunities and Risks of Creating and Sharing Information Online'),
#  (0.09553591817159436, 'Arab World Competitiveness Report 2013'),
#  (0.08615502582955287, 'Top Ten Urban Innovations'),
#  (0.08556951973450544, 'Annual Report 2011-2012'),
#  (0.08556951973450544, 'Annual Report 2011-2012 - Chinese')]
